# %%
import os 
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'CompanyDFprint.settings')
django.setup()

# %%
from Api.models import Data

# %%
Data.objects.create(Name='ICC1', Domain='icc.com1', Facebook='fb1', Instagram='insta1')
# Out:
# <Data: Data object (3)>

# %%
import json
with open('data.json') as f:
    data = json.load(f)

# %%
Data.objects.create(**data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     400                         if cls is not object \
#     401                                 and callable(cls.__dict__.get('__repr__')):
# --> 402                             return _repr_pprint(obj, self, cycle)
#     403
#     404             return _default_pprint(obj, self, cycle)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     695     """A pprint that just redirects to the normal repr function."""
#     696     # Find newlines and replace them with p.break_()
# --> 697     output = repr(obj)
#     698     for idx,output_line in enumerate(output.splitlines()):
#     699         if idx:
#
# ~/anaconda3/lib/python3.7/site-packages/django/db/models/base.py in __repr__(self)
#     517
#     518     def __repr__(self):
# --> 519         return '<%s: %s>' % (self.__class__.__name__, self)
#     520
#     521     def __str__(self):
#
# TypeError: __str__ returned non-string (type list)

# %%
data
# Out:
# {'Name': ['Aachi Group (Aachi Masala Foods Pvt Ltd)',
#   'ABP Pvt Ltd (Anandabazar Patrika) (ABP)',
#   'Advaith Motors Pvt. Ltd',
#   'Allanasons Pvt Ltd',
#   'Alukkas Enterprises Pvt Ltd (Jos Alukkas)',
#   'Amalgamated Plantations Pvt Ltd(Tata Group) (TATA)',
#   'Anand Automotive Pvt Ltd (Anand)',
#   'ANI Technologies Pvt Ltd (Ola cabs)',
#   'Balaji Wafers Pvt Ltd (Balaji Group)',
#   'Bikanervala Foods Pvt Ltd (Bikano)',
#   'Bluestar Diamonds Pvt Ltd',
#   'Brakes India Pvt Ltd (TVS)',
#   'Cavinkare Pvt Ltd',
#   'CRI Pumps Pvt Ltd',
#   'Daily Thanthi Pvt Ltd',
#   'Dorf Ketal Chemicals India Pvt Ltd',
#   'Ebix Travels Pvt Ltd ( Via.com ) (Ebix)',
#   'Fabindia Overseas Pvt Ltd',
#   'Fena Pvt Ltd',
#   'Forbes Marshall Pvt Ltd',
#   'Haldiram Foods International Pvt Ltd',
#   'Haldiram Manufacturing Co.Pvt Ltd',
#   'Hamilton Housewares Pvt Ltd ( Milton )',
#   'Hari Krishna Exports Pvt Ltd',
#   'Himalaya Drug Company Pvt Ltd',
#   'Hindustan Coca-Cola Beverages Pvt Ltd',
#   'Hiranandani Developers Pvt Ltd',
#   'Jaquar & Company Pvt Ltd',
#   'John Distilleries Pvt Ltd',
#   'Leayan Global Pvt Ltd ( Red Chief Shoes )',
#   'Lifestyle International Pvt Ltd',
#   'Luxor Writing Instruments Pvt Ltd (Luxor)',
#   'Mahashian Di Hatti Pvt Ltd (MDH)',
#   'MakeMyTrip India Pvt Ltd',
#   'Malabar Gold Pvt Ltd',
#   'Mother Dairy Fruit & Vegetable Pvt Ltd',
#   'Parle Agro Pvt Ltd',
#   'Parle Products Pvt Ltd',
#   'Riya Travel and Tours India Pvt Ltd',
#   'Safexpress Pvt Ltd',
#   'Shahi Exports Pvt Ltd',
#   'Shree Sant Kripa Appliances Pvt Ltd (Syska) (Syska)',
#   'Sony Pictures Networks India Pvt Ltd (Sony)',
#   'Star India Pvt Ltd (STAR)',
#   'Sterling And Wilson Pvt Ltd (SP)',
#   'Suguna Foods Pvt Ltd',
#   'Sunbeam Auto Pvt Ltd (Hero)',
#   'Afriso India Pvt Ltd',
#   'Afro-Asian Insurance and Reinsurance Brokers India Pvt Ltd',
#   'AGA Assistance India Pvt Ltd',
#   'Agfa HealthCare India Pvt Ltd',
#   'Aggreko Energy Rental India Pvt Ltd',
#   'Agilent Technologies India Pvt Ltd',
#   'Agiliance India Pvt Ltd',
#   'Agilisys IT Services India Pvt Ltd',
#   'Agility Logistics Pvt Ltd',
#   'AGM India Advisors Pvt Ltd',
#   'Agnicient Technologies Pvt Ltd',
#   'Agnisys Technology Pvt Ltd',
#   'AGNITY Communication Pvt Ltd',
#   'Agreeya Solutions India Pvt Ltd',
#   'Agri Best India Pvt Ltd',
#   'Agrilink Asia Pvt. Ltd',
#   'AGS Four Winds India Pvt Ltd'],
#  'Domain': ['http://www.aachigroup.com',
#   'http://www.abp.in',
#   'http://www.advaithhyundai.com',
#   'http://www.allana.com',
#   'http://www.josalukkasonline.com',
#   'http://www.amalgamatedplantations.co.in',
#   'http://www.anandgroupindia.com',
#   'http://www.olacabs.com',
#   'http://www.balajiwafers.com',
#   'http://www.bikanervala.com',
#   'http://www.bluestardiamonds.com',
#   'http://www.brakesindia.com',
#   'http://www.cavinkare.com',
#   'http://www.cripumps.com',
#   'http://www.dailythanthi.com',
#   'http://www.dorfketal.com',
#   'http://www.via.com',
#   'http://www.fabindia.com',
#   'http://www.fena.com',
#   'http://www.forbesmarshall.com',
#   'http://www.haldirams.com',
#   'http://www.haldirams.com',
#   'http://www.hamiltonindia.in',
#   'http://hk.co',
#   'http://www.himalayawellness.com',
#   'http://www.hindustancoca-cola.com',
#   'http://www.hiranandani.com',
#   'http://www.jaquar.com',
#   'http://www.jdl.in',
#   'http://www.leayan.com',
#   'http://www.lifestylestores.com',
#   'http://www.luxor.in',
#   'http://mdhspices.com',
#   'http://www.makemytrip.com',
#   'http://www.malabargoldanddiamonds.com',
#   'http://www.motherdairy.com',
#   'http://www.parleagro.com',
#   'http://www.parleproducts.com',
#   'http://www.riya.travel',
#   'http://www.safexpress.com',
#   'http://www.shahi.co.in',
#   'http://sskgroup.in',
#   'http://sonypicturesnetworks.com',
#   'http://www.startv.com',
#   'http://www.sterlingandwilson.com',
#   'http://www.sugunapoultry.com',
#   'http://www.sunbeamauto.com',
#   'http://www.tvs.in',
#   'http://venkys.com',
#   'http://www.viacom18.com',
#   'http://www.wns.com',
#   'http://www.yatra.com',
#   'http://www.247.ai',
#   'http://www.3acomposites.com',
#   'http://www.3disystems.com',
#   'http://www.3i.com',
#   'http://www.3pillarglobal.com',
#   'http://www.3tier.com',
#   'http://www.nsight-inc.com',
#   'http://www.6degreesit.com',
#   'http://www.7n.com',
#   'http://www.a-eberle.de',
#   'http://www.hartrodt.com',
#   'http://www.araymond-automotive.com',
#   'http://www.faber-castell.in',
#   'http://aanddindia.in',
#   'http://www.menariniapac.com',
#   'http://www.aschulman.com',
#   'http://www.a2mac1.com',
#   'http://www.digital-x.com',
#   'http://www.aafintl.com',
#   'http://aagengg.com',
#   'http://www.aam.com',
#   'http://www.aamctraining.edu.au',
#   'http://aatco.om',
#   'http://www.aatek.de',
#   'http://www.abmauri.in',
#   'http://www.itsabacus.com',
#   'http://www.abbott.com',
#   'http://www.abercrombiekent.com',
#   'http://www.acer.com',
#   'http://www.aciworldwide.com',
#   'http://ackmprojects.com',
#   'http://www.aco.in',
#   'http://www.acrohrindia.com',
#   'http://www.acrotechnologies.com',
#   'http://www.acrotrend.com',
#   'http://www.wittyparrot.com',
#   'http://www.aircharterservice.co.in',
#   'http://www.actfive.co.jp',
#   'http://www.actia.com',
#   'http://www.actiance.com',
#   'http://www.act.is',
#   'http://www.activdoctorsonline.in',
#   'http://activair.in',
#   'http://www.actuant.com',
#   'http://www.acty-sys.co.in',
#   'http://acumen.org',
#   'http://www.acurussolutions.com',
#   'http://www.acusisindia.com',
#   'http://adssensortek.com',
#   'http://www.adtran.com',
#   'http://www.aftwatermist.com',
#   'http://advancedmouldtech.com',
#   'http://www.advancedsystek.com',
#   'http://www.advanide.com',
#   'http://www.advantech.com',
#   'http://www.advantumhealth.com',
#   'http://www.adventinternational.com',
#   'http://www.aecom.com',
#   'http://www.advanced-energy.com',
#   'http://www.aeoncredit.co.in',
#   'http://www.aequor.com',
#   'http://www.aerzenindia.com',
#   'http://www.aes-india.com',
#   'http://www.aesseal.com',
#   'http://aet.eu',
#   'http://www.aet-tankers.com',
#   'http://www.aetins.com',
#   'http://www.afconsult.com',
#   'http://www.affinity.com',
#   'http://www.cartridgeworld.in',
#   'http://www.afourtech.com',
#   'http://www.afriso.de',
#   'http://www.afroasian-insurance.co.in',
#   'http://www.allianz-assistance.in',
#   'http://www.agfa.com',
#   'http://www.aggreko.com',
#   'http://www.agilent.com',
#   'http://',
#   'http://www.agilisys.co.uk/about/offices/',
#   'http://www.agilitylogistics.com',
#   'http://www.agm.com',
#   'http://www.agnicient.com',
#   'http://www.agnisys.com',
#   'http://agnityglobal.com',
#   'http://www.agreeya.com',
#   'http://www.agri-best.com',
#   'http://www.agrilinkindia.com',
#   'http://www.agsmovers.com'],
#  'Facebook': ['https://www.facebook.com/aachiproducts',
#   'None',
#   'https://www.facebook.com/AdvaithHyundai/',
#   'None',
#   'https://www.facebook.com/josalukkasjewellery',
#   'https://www.facebook.com/AmalgamatedPlantations',
#   'https://www.facebook.com/hashtag/futureready',
#   'https://www.facebook.com/Olacabs',
#   'https://www.facebook.com/BalajiWafers',
#   'None',
#   'None',
#   'None',
#   'https://www.facebook.com/CavinKareIndia',
#   'https://www.facebook.com/WestSideRidesTX/',
#   'https://www.facebook.com/dailythanthi',
#   'None',
#   'None',
#   'None',
#   'https://www.facebook.com/FenaHiLena/',
#   'https://www.facebook.com/ForbesMarshall/',
#   'https://www.facebook.com/haldiramsofficial',
#   'https://www.facebook.com/haldiramsofficial',
#   'None',
#   'https://www.facebook.com/HKDiamonds',
#   'None',
#   'https://www.facebook.com/HCCBOfficial/',
#   'https://www.facebook.com/HiranandaniDevelopers/',
#   'https://www.facebook.com/JaquarGroup',
#   'https://www.facebook.com/pauljohnwhisky/',
#   'None',
#   'https://www.facebook.com/lifestylestores',
#   'https://www.facebook.com/LuxorIndia/',
#   'https://www.facebook.com/MDHSpice',
#   'https://www.facebook.com/makemytrip/',
#   'https://www.facebook.com/malabargoldanddiamonds',
#   'https://www.facebook.com/MotherDairy/',
#   'None',
#   'None',
#   'https://www.facebook.com/RiyaTheTravelExpertIndia',
#   'https://www.facebook.com/SafexpressPrivateLimited',
#   'None',
#   'None',
#   'https://www.facebook.com/sonypicturesnetworks',
#   'https://www.facebook.com/StarTVNetworkIndia/',
#   'https://www.facebook.com/SterlingandWilsonofficial/?ref=hl',
#   'None',
#   'None',
#   'None',
#   'None',
#   'https://www.facebook.com/viacom18digital/',
#   'None',
#   'https://www.facebook.com/Yatra',
#   'https://www.facebook.com/247US',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'https://www.facebook.com/nsightinc',
#   'https://www.facebook.com/6DegreesIT/',
#   'https://www.facebook.com/7NAgents/',
#   'None',
#   'https://www.facebook.com/hartrodt/',
#   'https://www.facebook.com/ARaymondNetwork',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'https://www.facebook.com/AAG-Engineering-Technology-334751183365800',
#   'https://www.facebook.com/americanaxle',
#   'https://www.facebook.com/aamctrainingindia',
#   'None',
#   'None',
#   'https://www.facebook.com/ABMauriIndia',
#   'https://www.facebook.com/Abacus-Consultancy-Services-1694977804077591/',
#   'https://www.facebook.com/Abbott',
#   'https://www.facebook.com/AbercrombieKent',
#   'https://www.facebook.com/acerindia',
#   'None',
#   'None',
#   'https://www.facebook.com/ACOgroup.in/',
#   'None',
#   'None',
#   'https://www.facebook.com/Acrotrend-266708496683409/',
#   'https://www.facebook.com/wittyparrotapp',
#   'https://www.facebook.com/acsaircharter',
#   'None',
#   'https://www.facebook.com/ACTIAGroup',
#   'https://www.facebook.com/SmarshInc/',
#   'None',
#   'https://www.facebook.com/activdoctorsonlineindia',
#   'None',
#   'None',
#   'None',
#   'https://www.facebook.com/acumenfund',
#   'https://www.facebook.com/Acurus-Solutions-Inc-200279660329469',
#   'None',
#   'None',
#   'https://www.facebook.com/adtran.inc/',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'https://www.facebook.com/AdvantumHealth/',
#   'None',
#   'https://www.facebook.com/sharer/sharer.php?u=http%3A%2F%2Fwww.aecom.com%2F',
#   'None',
#   'https://www.facebook.com/AeonCreditServiceIndia/',
#   'https://www.facebook.com/aequortechnologies',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'https://www.facebook.com/AETINS.Sdn.Bhd/',
#   'https://www.facebook.com/afkarriar/',
#   'https://www.facebook.com/AffinityMediaGr/?ref=settings',
#   'https://www.facebook.com/CartridgeWorldNA',
#   'https://www.facebook.com/AFourTechnologies/',
#   'https://www.facebook.com/afrisoDE',
#   'None',
#   'None',
#   'None',
#   'https://www.facebook.com/aggrekoglobal/',
#   'https://www.facebook.com/Agilent.Tech',
#   'None',
#   'None',
#   'https://www.facebook.com/Agility-461523027688878',
#   'None',
#   'None',
#   'None',
#   'https://www.facebook.com/agnity/',
#   'None',
#   'None',
#   'None',
#   'https://www.facebook.com/AGSInternationalMovers/'],
#  'Instagram': ['None',
#   'None',
#   'https://www.instagram.com/advaithhyundai/',
#   'None',
#   'None',
#   'https://www.instagram.com/amalgamatedplantations/',
#   'https://www.instagram.com/explore/tags/sujanlife/',
#   'https://www.instagram.com/olacabs',
#   'https://www.instagram.com/BalajiWafers',
#   'None',
#   'None',
#   'None',
#   'https://www.instagram.com/cavinkareindia/',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'https://www.instagram.com/fenahilena/',
#   'https://www.instagram.com/forbesmarshallglobal',
#   'https://www.instagram.com/haldirams_nagpur/',
#   'https://www.instagram.com/haldirams_nagpur/',
#   'None',
#   'https://www.instagram.com/hkdiamonds',
#   'None',
#   'https://www.instagram.com/hccb_official/',
#   'https://www.instagram.com/hiranandanidevelopers/',
#   'https://www.instagram.com/jaquargroup/',
#   'https://www.instagram.com/pauljohnwhisky/',
#   'None',
#   'https://www.instagram.com/lifestylestores',
#   'https://www.instagram.com/luxor_india/',
#   'None',
#   'None',
#   'https://www.instagram.com/malabargoldanddiamonds/',
#   'https://www.instagram.com/motherdairy/',
#   'None',
#   'None',
#   'https://www.instagram.com/riyatravel/',
#   'None',
#   'None',
#   'None',
#   'https://www.instagram.com/sonypicturesnetworks/',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'https://www.instagram.com/viacom18/',
#   'None',
#   'https://www.instagram.com/yatradotcom/',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'https://www.instagram.com/hartrodt/',
#   'None',
#   'https://www.instagram.com/fabercastellglobal/',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'https://www.instagram.com/AKTravel_USA/',
#   'https://www.instagram.com/Acer/',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'https://www.instagram.com/acumenorg',
#   'None',
#   'None',
#   'None',
#   'https://www.instagram.com/adtraninc/',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'https://www.instagram.com/aecom/',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None']}
